# %%
import time
import tushare as ts
import datetime
import pandas as pd
import os
import tensorflow as tf
from collections import namedtuple
import numpy as np

# %%
if os.path.exists('601318.SH_5min.csv'):
    data = pd.read_csv('601318.SH_5min.csv', index_col=0)
    print('Read sussessful')
#     print('head: \n', data.head())
#     print('tail: \n', data.tail())
else:
    print('File not exist')
# Out:
# Read sussessful

# %%
data.head(5)
# Out:
#      ts_code           trade_time   open  close   high    low       vol  \
# 0  601318.SH  2019-10-22 15:00:00  90.15  90.29  90.29  90.15  966545.0
# 1  601318.SH  2019-10-22 14:55:00  90.12  90.15  90.19  90.11  735530.0
# 2  601318.SH  2019-10-22 14:50:00  90.10  90.11  90.12  90.07  558033.0
# 3  601318.SH  2019-10-22 14:45:00  90.10  90.10  90.14  90.06  640738.0
# 4  601318.SH  2019-10-22 14:40:00  90.25  90.12  90.25  90.06  724000.0
#
#        amount
# 0  87224082.0
# 1  66309263.0
# 2  50276229.0
# 3  57733317.0
# 4  65254508.0

# %%
def get_time(t):
    time = datetime.datetime.strptime(t, '%Y-%m-%d %H:%M:%S')
    minus_9_30 = (int(time.strftime('%H'))-9) * 12 + int(time.strftime('%M')) / 5 - 6
    return minus_9_30 if minus_9_30 < 25 else minus_9_30 - 18

class Observations:
    def __init__(self, index, is_hold, wait_time, trade_price):
        # is_hold: 是否持有股票，1表示持有，0表示未持有
        # trade_price: 距离上次操作的时间（多少个5分钟）
        # trade_price: 上次交易价格
        
        self.index = index
        self.is_hold = is_hold 
        self.wait_time = wait_time
        self.trade_price = trade_price

    def values(self, history_data, length):
        # history_data: DataFram 索引越靠前日期越靠后
        # 返回数据为 length * 6 + 3， 前 length * 6 为每日的 time，open， close， high， low， vol-10000
        # 其中 time 为 0 到 48， 表示一天中的第几个5分钟
        # 最后三位分别是 is_hold * 100，即100为持仓, 持仓是否过夜，100为过夜
        
        recent_data = history_data[['trade_time', 'open', 'high', 'low', 'close', 'vol']][
            self.index: self.index+length]
        recent_data['vol'] = recent_data['vol']/10000
        recent_data['trade_time'] = recent_data['trade_time'].apply(lambda x: get_time(x))
        is_pass_night = self.wait_time > 48 or self.wait_time > recent_data['trade_time'].iloc[0]
        return np.hstack([np.array(recent_data.values).reshape(1,-1),
                          np.array([[self.is_hold*100, 100 if is_pass_night else 0, self.trade_price]])])
        
    def decode(self, history_data, length, log=False):
        recent_data = history_data[['trade_time', 'open', 'high', 'low', 'close', 'vol']][
            self.index: self.index+length]
        recent_data['trade_time'] = recent_data['trade_time'].apply(lambda x: get_time(x))

        if log:
            print('recent data is :\n', recent_data)
            print('')

            if self.is_hold:
                print('Hold stock for {} minutes， purchase price is {}.'.format(
                    self.wait_time*5, self.trade_price))
            else:
                print('Dosen\'t hold any thing.')
        return recent_data
        
    def __str__(self):
        return 'index: {}, is_hold: {}, wait_time: {}, trade_price: {}\n'.format(
            self.index, self.is_hold, self.wait_time, self.trade_price)
    
    def __repr__(self):
        return self.__str__()

# %%
# Observation test
# index， is_hold， wait_time， trade_price
# obs = Observations(*[1, 1, 0, 89])
# next_obs = Observations(*[0, 1, 1, 89])
# print(obs.values(data, 3))
# print(next_obs.values(data, 3))

# %%
class Actions:
    
    def __init__(self, action_prob):
        # 买、卖、持有的几率
        self.p_buy = action_prob[0]
        self.p_sell = action_prob[1] 
        self.p_hold = 1 - action_prob[0] - action_prob[1] 
        
        self.action_choose = np.random.choice(['buy', 'sell', 'hold'],
                                              p=[self.p_buy, self.p_sell, self.p_hold])
# Deubg 
        print('action_prob: {}, action is {}'.format(action_prob, self.action_choose))
    
    def choose(self):

        return self.action_choose

# %% [markdown]
# + 注意： 交易默认只买 100 股，手续费默认

# %%
def calc_reward_batch(obs, next_obs, history_data):
    # obs 和 next_obs 为 Observation 类
    
    fee = obs.trade_price * 0.02 if next_obs.wait_time == 1 else 0
    if obs.is_hold == 1:
        delta_price = (next_obs.decode(history_data, 1).close.iloc[0]
                       - obs.decode(history_data, 1).close.iloc[0]) * 100
        return delta_price - fee
    else:
        return -fee

# %%
# 计算 reward 测试
# obs.decode(data, 3, log=True)
# next_obs.decode(data, 3, log=True)
# calc_reward_batch(obs, next_obs, data)

# %%
class Env:
    def __init__(self, hps, history_data):
        self._hps = hps
        self._history_data = history_data
        
        self._observations_dim = hps.days * 6 + 3
        self._actions_dim = 3
        return
    
    def reset(self):
        index = self._history_data.shape[0] - self._hps.days - 1
        return Observations(index=index, is_hold=0, wait_time=0, trade_price=0)
    
    def step(self, obs, action):
        # 输入为 Observations 类和 Actions 类
        # 返回值为 next observations， reward， done
        index, is_hold, wait_time, trade_price = obs.index, obs.is_hold, obs.wait_time, obs.trade_price
        done = True if index == 0 else False
        action_choose = action.choose()
        
        if is_hold == 1 and action_choose == 'sell':
            current_time = get_time(self._history_data['trade_time'].iloc[index])
            is_pass_night = wait_time>48 or wait_time>current_time
            if is_pass_night:
                is_hold = 0  # 卖掉了
                wait_time = 0  # 时间清0
                trade_price = self._history_data['close'].iloc[index]  # 以当前的收盘价为成交加个
            else:
                pass # 不做操作，类似 hold
        elif is_hold == 0 and action_choose == 'buy':
            is_hold = 1
            wait_time = 0
            trade_price = self._history_data['close'].iloc[index]
        else:
            pass # 不做操作
        
        next_obs = Observations(index-1, is_hold, wait_time+1, trade_price)

        return next_obs, calc_reward_batch(obs, next_obs, self._history_data), done
    
    @property
    def observations_dim(self):
        return self._observations_dim
    
    @property
    def actions_dim(self):
        return self._actions_dim

# %%
class DataSet:
    def __init__(self, hps, history_data):
        self._buffer = []
        self._length = 0
        self._hps = hps
        self._history_data = history_data
        return 
    
    def get_batch(self, nums):
        assert self._length > 1, 'Length of data is {} which is not enough. \
        Data need at least {}'.format(self._length, 2)
        
        rand_idx = np.random.randint(0, self._length-1, nums)
        obs = np.vstack([self._buffer[x].values(
            self._history_data, self._hps.days) for x in rand_idx])
        
        next_obs = np.vstack([self._buffer[x+1].values(
            self._history_data, self._hps.days) for x in rand_idx])
        
        reward = np.array([calc_reward_batch(self._buffer[x], self._buffer[x+1], self._history_data)
                           for x in rand_idx])
    
        return obs, next_obs, reward
    
    def add_data(self, obs):
        # obs 为 Observation 类
        self._buffer.append(obs)
        self._length += 1
        return

# %%
# DataSet test

# obs = Observations(*[1, 1, 0, 89])
# next_obs = Observations(*[0, 1, 1, 89])
# data_set = DataSet(hps, data)
# data_set.add_data(obs)
# data_set.add_data(obs)
# data_set.add_data(obs)
# print(data_set._buffer)
# obs.trade_price = 100
# print(data_set._buffer)
# print(obs)
# data_set.add_data(obs)
# obs, next_obs, reward = data_set.get_batch(2)
# print('obs: \n', obs)
# print('\nnext_obs: \n', next_obs)
# print('\nreward: \n', reward)

# %%
class Model:
    def __init__(self, env, hps):
        self._env = env
        self._hps = hps
        
        self.global_step = tf.Variable(0, name='global_step', trainable=False)
        self.action, self.Q, self.action_loss, self.Q_loss, self.action_train_opt, self.Q_train_opt = \
            self._build_graph()
        self._sess, self._summary_writer = self._sess_setup()
        return
    
    def train(self, iteration, data_set):
        for i in range(iteration):
            obs, next_obs, reward = data_set.get_batch(self._hps.batch_size)
            action_loss, Q_loss = self._train_one_step(obs, next_obs, reward)
            print('action_loss: {}, Q_loss : {}'.format(action_loss, Q_loss))

        return
    
    def test(self, data):
        return
    
    def predict(self, obs):
        action_prob = self._sess.run(self.action, {self._observations_ph: obs})
        return action_prob
    
    def _train_one_step(self, obs, next_obs, reward):
        feed_dict = {self._observations_ph: obs,
                    self._next_observations_ph: next_obs,
                    self._rewards_ph: reward}
        
        action_loss, Q_loss, _, _ = self._sess.run([self.action_loss, self.Q_loss,
                                                    self.action_train_opt, self.Q_train_opt],
                                                   feed_dict)
        return action_loss, Q_loss
    
    def _sess_setup(self):
        saver = tf.train.Saver(max_to_keep=3)
        sv = tf.train.Supervisor(logdir=self._hps.train_dir,
                   is_chief=True,
                   saver=saver,
                   summary_op=None,
                   save_summaries_secs=600, # save summaries for tensorboard every 60 secs
                   save_model_secs=600, # checkpoint every 600 secs
                   global_step=self.global_step,
                   init_feed_dict= None
                   )
        summary_writer = sv.summary_writer
        sess = sv.prepare_or_wait_for_session()
    
        return sess, summary_writer
    
    def _create_placeholders(self):
        observations_dim = self._env.observations_dim
        actions_dim = self._env.actions_dim

        
        self._observations_ph = tf.placeholder(
            tf.float32,
            shape=(None, observations_dim),
            name='observation',
        )
        self._next_observations_ph = tf.placeholder(
            tf.float32,
            shape=(None, observations_dim),
            name='next_observation',
        )
#         self._actions_ph = tf.placeholder(
#             tf.float32,
#             shape=(None, actions_dim),
#             name='actions',
#         )
        self._rewards_ph = tf.placeholder(
            tf.float32,
            shape=(None, ),
            name='rewards',
        )
        return
    
#     def _linear(self, arg, output_size, activation, scope=None, reuse=False):
#         input_size = arg.get_shape().as_list()[1]
#         print('input_size', input_size)
#         trunc_norm_init = tf.truncated_normal_initializer(stddev=self._hps.trunc_norm_init_std)
        
#         with tf.variable_scope(scope or "Linear", reuse=reuse):
#             matrix = tf.get_variable("Matrix", [input_size, output_size])
#             res = tf.matmul(arg, matrix)
#             bias_term = tf.get_variable("Bias", [output_size],
#                                         initializer=trunc_norm_init)
#         return activation(res + bias_term)
        
    def _action_Q_output(self, state, reuse=False):
        
        with tf.variable_scope('hidden_state', reuse=tf.AUTO_REUSE):
            hidden_states = tf.layers.dense(state, self._hps.hidden_dim,
                                           activation=tf.nn.sigmoid, name='state_hidden_layer')
            
        with tf.variable_scope('action_output', reuse=tf.AUTO_REUSE):
            actions = tf.nn.softmax(tf.layers.dense(hidden_states, self._env.actions_dim,
                                                    activation=tf.nn.sigmoid, name='action_output_layer'))
            
        with tf.variable_scope('Q_output', reuse=tf.AUTO_REUSE):
            Q = tf.layers.dense(tf.concat([hidden_states, actions], axis=1), 1,
                                           activation=None, name='Q_output_layer')
        return hidden_states, actions, Q
        
    def _build_graph(self):
        self._create_placeholders()
        _, action, Q = self._action_Q_output(self._observations_ph)
        _, _, next_Q = self._action_Q_output(self._next_observations_ph)
        
        # Calculate action loss and Q loss
        action_loss = -tf.reduce_sum(tf.squeeze(Q), axis=0)

        Q_loss = tf.reduce_sum(self._rewards_ph + tf.squeeze(self._hps.gamma * next_Q - Q), axis=0)

        
        # Get update option
        t_vars = tf.trainable_variables()
        action_vars = [var for var in t_vars 
                       if var.name.startswith('hidden_state') or var.name.startswith('action_output')]
        
        Q_vars = [var for var in t_vars 
                  if var.name.startswith('hidden_state') or var.name.startswith('Q_output')] 
        
        action_train_opt = tf.train.AdamOptimizer(self._hps.learning_rate).minimize(
            action_loss, var_list = action_vars)
        
        Q_train_opt = tf.train.AdamOptimizer(self._hps.learning_rate).minimize(
            action_loss, var_list = Q_vars)
        
        return action, Q, action_loss, Q_loss, action_train_opt, Q_train_opt

# %%
class Agent:
    def __init__(self, hps, env, history_data):
        self._hps = hps
        self._env = env
        self._history_data = history_data
        self._data_set = DataSet(hps, history_data)
        self._model = Model(env, hps)
        return
    
    def step(self, obs):
        self._data_set.add_data(obs)
        action_prob = self._model.predict(obs.values(self._history_data, self._hps.days))
        action = Actions(action_prob[0])
        
        if self._data_set._length > 20:
            self._model.train(1, self._data_set)
            
        return action

# %%
hps = {'trunc_norm_init_std': 1e-4,
      'hidden_dim': 20,
      'train_dir': './model',
      'gamma': 0.99,
      'learning_rate': 0.003,
      'batch_size': 10,
      'days': 20}
hps = namedtuple("HParams", hps.keys())(**hps)

# %%
# For model test
# env = Env(hps, data)
# obs = env.reset()
# obs.values(data, hps.days)

# %%
env = Env(hps, data)
agent = Agent(hps, env, data)
# Out:
# WARNING:tensorflow:From <ipython-input-12-8cbd254bac9a>:46: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# INFO:tensorflow:Restoring parameters from ./model/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Starting standard services.
# INFO:tensorflow:Saving checkpoint to path ./model/model.ckpt
# INFO:tensorflow:Starting queue runners.
# INFO:tensorflow:global_step/sec: 0

# %%
obs = env.reset()
rewards = []
reward_sum = 0
n = 100000
for i in range(n):
    print('{}/{}'.format(i, n))
    action = agent.step(obs)
    obs, reward, done = env.step(obs, action)
    rewards.append(reward)
    reward_sum += reward
    print('reward is {:.2f}, reward sum is {:.2f}, time is {}, close is {}\n'.format(
        reward, reward_sum, obs.decode(data, 1)['trade_time'].iloc[0], obs.decode(data, 1)['close'].iloc[0]))
# Out:
# 0/100000
# action_prob: [0.39657342 0.38204104 0.22138563], action is sell
# reward is -0.00, reward sum is 0.00, time is 21.0, close is 28.28
#
# 1/100000
# action_prob: [0.43359554 0.3283313  0.23807319], action is buy
# reward is -0.00, reward sum is 0.00, time is 22.0, close is 28.27
#
# 2/100000
# action_prob: [0.4135311  0.37282205 0.21364687], action is buy
# reward is 8.00, reward sum is 8.00, time is 23.0, close is 28.35
#
# 3/100000
# action_prob: [0.4195073  0.33264577 0.24784693], action is sell
# reward is 2.00, reward sum is 10.00, time is 24.0, close is 28.37
#
# 4/100000
# action_prob: [0.45859054 0.33935025 0.20205916], action is sell
# reward is 5.00, reward sum is 15.00, time is 25.0, close is 28.42
#
# 5/100000
# action_prob: [0.42529476 0.34749025 0.22721496], action is sell
# reward is -8.00, reward sum is 7.00, time is 26.0, close is 28.34
#
# 6/100000
# action_prob: [0.385062   0.39691684 0.21802115], action is buy
# reward is 1.00, reward sum is 8.00, time is 27.0, close is 28.35
#
# 7/100000
# action_prob: [0.42696962 0.3387488  0.2342816 ], action is buy
# reward is -15.00, reward sum is -7.00, time is 28.0, close is 28.2
#
# 8/100000
# action_prob: [0.43216905 0.34323046 0.22460052], action is buy
# reward is -17.00, reward sum is -24.00, time is 29.0, close is 28.03
#
# 9/100000
# action_prob: [0.4736129  0.3177627  0.20862438], action is sell
# reward is -3.00, reward sum is -27.00, time is 30.0, close is 28.0
#
# 10/100000
# action_prob: [0.44342482 0.35030502 0.20627017], action is sell
# reward is 1.00, reward sum is -26.00, time is 31.0, close is 28.01
#
# 11/100000
# action_prob: [0.44725478 0.34031612 0.21242912], action is sell
# reward is 4.00, reward sum is -22.00, time is 32.0, close is 28.05
#
# 12/100000
# action_prob: [0.41808483 0.3475284  0.23438677], action is sell
# reward is 6.00, reward sum is -16.00, time is 33.0, close is 28.11
#
# 13/100000
# action_prob: [0.43655807 0.3430794  0.2203626 ], action is sell
# reward is -2.00, reward sum is -18.00, time is 34.0, close is 28.09
#
# 14/100000
# action_prob: [0.40762   0.3556936 0.2366863], action is sell
# reward is 1.00, reward sum is -17.00, time is 35.0, close is 28.1
#
# 15/100000
# action_prob: [0.4102923  0.35459825 0.2351095 ], action is buy
# reward is 2.00, reward sum is -15.00, time is 36.0, close is 28.12
#
# 16/100000
# action_prob: [0.45056507 0.3209462  0.2284888 ], action is sell
# reward is 17.00, reward sum is 2.00, time is 37.0, close is 28.29
#
# 17/100000
# action_prob: [0.44084582 0.32373106 0.2354231 ], action is sell
# reward is -9.00, reward sum is -7.00, time is 38.0, close is 28.2
#
# 18/100000
# action_prob: [0.43157905 0.34136435 0.22705661], action is sell
# reward is -15.00, reward sum is -22.00, time is 39.0, close is 28.05
#
# 19/100000
# action_prob: [0.44381896 0.32697847 0.22920255], action is sell
# reward is 18.00, reward sum is -4.00, time is 40.0, close is 28.23
#
# 20/100000
# action_prob: [0.4842828  0.28983006 0.22588715], action is hold
# action_loss: 0.29402637481689453, Q_loss : -1.4653364419937134
# reward is 7.00, reward sum is 3.00, time is 41.0, close is 28.3
#
# 21/100000
# action_prob: [0.44349325 0.32860988 0.22789694], action is sell
# action_loss: -14.325166702270508, Q_loss : -42.01300048828125
# reward is -3.00, reward sum is 0.00, time is 42.0, close is 28.27
#
# 22/100000
# action_prob: [0.40947187 0.3692083  0.22131984], action is sell
# action_loss: -21.872943878173828, Q_loss : -10.362635612487793
# reward is 3.00, reward sum is 3.00, time is 43.0, close is 28.3
#
# 23/100000
# action_prob: [0.37449896 0.3847904  0.24071066], action is hold
# action_loss: -24.465728759765625, Q_loss : 1.4811983108520508
# reward is 1.00, reward sum is 4.00, time is 44.0, close is 28.31
#
# 24/100000
# action_prob: [0.36157703 0.3886789  0.24974407], action is sell
# action_loss: -25.441612243652344, Q_loss : 13.74570369720459
# reward is 7.00, reward sum is 11.00, time is 45.0, close is 28.38
#
# 25/100000
# action_prob: [0.3600916 0.3917537 0.2481547], action is buy
# action_loss: -25.876596450805664, Q_loss : 8.741231918334961
# reward is 22.00, reward sum is 33.00, time is 46.0, close is 28.6
#
# 26/100000
# action_prob: [0.35857192 0.39482963 0.24659844], action is hold
# action_loss: -26.31249237060547, Q_loss : 67.73687744140625
# reward is 30.00, reward sum is 63.00, time is 47.0, close is 28.9
#
# 27/100000
# action_prob: [0.35701573 0.39790374 0.24508055], action is hold
# action_loss: -26.749042510986328, Q_loss : 71.73251342773438
# reward is -5.00, reward sum is 58.00, time is 48.0, close is 28.85
#
# 28/100000
# action_prob: [0.3554212  0.40097383 0.24360499], action is sell
# action_loss: -27.18600845336914, Q_loss : 137.7281494140625
# reward is -15.00, reward sum is 43.00, time is 0.0, close is 28.7
#
# 29/100000
# action_prob: [0.35378677 0.4040384  0.24217485], action is buy
# action_loss: -27.623212814331055, Q_loss : 91.7237777709961
# reward is 39.00, reward sum is 82.00, time is 1.0, close is 29.09
#
# 30/100000
# action_prob: [0.37130922 0.4035788  0.22511199], action is hold
# action_loss: -28.0605411529541, Q_loss : 2.719393730163574
# reward is 1.00, reward sum is 83.00, time is 2.0, close is 29.1
#
# 31/100000
# action_prob: [0.3696844 0.4062655 0.2240501], action is sell
# action_loss: -28.497901916503906, Q_loss : 36.715023040771484
# reward is 14.43, reward sum is 97.43, time is 3.0, close is 29.25
#
# 32/100000
# action_prob: [0.36802146 0.40894356 0.22303496], action is sell
# action_loss: -28.93523406982422, Q_loss : 120.36526489257812
# reward is 0.00, reward sum is 97.43, time is 4.0, close is 29.5
#
# 33/100000
# action_prob: [0.34682873 0.4162226  0.23694864], action is sell
# action_loss: -29.69986915588379, Q_loss : 29.7029972076416
# reward is 0.00, reward sum is 97.43, time is 5.0, close is 30.0
#
# 34/100000
# action_prob: [0.36457518 0.41427433 0.22115044], action is sell
# action_loss: -30.45778465270996, Q_loss : 37.450767517089844
# reward is 0.00, reward sum is 97.43, time is 6.0, close is 29.78
#
# 35/100000
# action_prob: [0.36235327 0.41706613 0.22058062], action is buy
# action_loss: -30.887849807739258, Q_loss : -9.31620979309082
# reward is -0.58, reward sum is 96.85, time is 7.0, close is 29.8
#
# 36/100000
# action_prob: [0.3411507  0.42525297 0.23359628], action is sell
# action_loss: -30.793956756591797, Q_loss : 30.581022262573242
# reward is -11.00, reward sum is 85.85, time is 8.0, close is 29.69
#
# 37/100000
# action_prob: [0.35909402 0.4222089  0.218697  ], action is buy
# action_loss: -31.438879013061523, Q_loss : 26.42506980895996
# reward is 21.00, reward sum is 106.85, time is 9.0, close is 29.9
#
# 38/100000
# action_prob: [0.35718602 0.42483807 0.21797587], action is buy
# action_loss: -32.799659729003906, Q_loss : 1.980581283569336
# reward is 10.00, reward sum is 116.85, time is 10.0, close is 30.0
#
# 39/100000
# action_prob: [0.35523477 0.42745942 0.2173058 ], action is sell
# action_loss: -34.569374084472656, Q_loss : -22.942548751831055
# reward is -9.00, reward sum is 107.85, time is 11.0, close is 29.91
#
# 40/100000
# action_prob: [0.35323656 0.43007267 0.21669081], action is buy
# action_loss: -35.181888580322266, Q_loss : 10.653234481811523
# reward is 0.00, reward sum is 107.85, time is 12.0, close is 29.91
#
# 41/100000
# action_prob: [0.35119292 0.43267778 0.21612926], action is buy
# action_loss: -35.57780456542969, Q_loss : -25.22296905517578
# reward is -3.00, reward sum is 104.85, time is 13.0, close is 29.88
#
# 42/100000
# action_prob: [0.34910628 0.43527484 0.21561883], action is buy
# action_loss: -36.28434371948242, Q_loss : -25.452167510986328
# reward is 20.00, reward sum is 124.85, time is 14.0, close is 30.08
#
# 43/100000
# action_prob: [0.34697786 0.43786362 0.21515852], action is sell
# action_loss: -36.6875114440918, Q_loss : 33.051124572753906
# reward is 12.00, reward sum is 136.85, time is 15.0, close is 30.2
#
# 44/100000
# action_prob: [0.34480998 0.44044408 0.21474594], action is sell
# action_loss: -37.090450286865234, Q_loss : 52.62909698486328
# reward is 2.00, reward sum is 138.85, time is 16.0, close is 30.22
#
# 45/100000
# action_prob: [0.34260532 0.44301596 0.21437876], action is buy
# action_loss: -37.4931755065918, Q_loss : -12.374929428100586
# reward is 10.00, reward sum is 148.85, time is 17.0, close is 30.32
#
# 46/100000
# action_prob: [0.34036624 0.44557887 0.21405485], action is hold
# action_loss: -37.89568328857422, Q_loss : 37.03904724121094
# reward is -22.00, reward sum is 126.85, time is 18.0, close is 30.1
#
# 47/100000
# action_prob: [0.33809546 0.44813251 0.21377206], action is buy
# action_loss: -38.2979736328125, Q_loss : -22.382976531982422
# reward is 11.00, reward sum is 137.85, time is 19.0, close is 30.21
#
# 48/100000
# action_prob: [0.3357955  0.45067617 0.21352829], action is buy
# action_loss: -38.7000617980957, Q_loss : 24.04739761352539
# reward is -9.00, reward sum is 128.85, time is 20.0, close is 30.12
#
# 49/100000
# action_prob: [0.33346924 0.45320922 0.2133215 ], action is hold
# action_loss: -39.10194778442383, Q_loss : -5.391016960144043
# reward is 8.00, reward sum is 136.85, time is 21.0, close is 30.2
#
# 50/100000
# action_prob: [0.33111945 0.45573086 0.21314968], action is sell
# action_loss: -39.50363540649414, Q_loss : 17.604965209960938
# reward is -12.00, reward sum is 124.85, time is 22.0, close is 30.08
#
# 51/100000
# action_prob: [0.32874912 0.4582401  0.21301083], action is sell
# action_loss: -39.90513229370117, Q_loss : -5.981053829193115
# reward is 11.00, reward sum is 135.85, time is 23.0, close is 30.19
#
# 52/100000
# action_prob: [0.3263612  0.46073583 0.21290295], action is sell
# action_loss: -40.30643081665039, Q_loss : 73.03134155273438
# reward is -1.00, reward sum is 134.85, time is 24.0, close is 30.18
#
# 53/100000
# action_prob: [0.32395884 0.46321702 0.21282412], action is sell
# action_loss: -40.707550048828125, Q_loss : 22.027324676513672
# reward is -36.00, reward sum is 98.85, time is 25.0, close is 29.82
#
# 54/100000
# action_prob: [0.32154533 0.46568224 0.21277241], action is hold
# action_loss: -41.108489990234375, Q_loss : -8.411088943481445
# reward is -7.00, reward sum is 91.85, time is 26.0, close is 29.75
#
# 55/100000
# action_prob: [0.31912386 0.46813023 0.21274592], action is hold
# action_loss: -41.509239196777344, Q_loss : -18.415096282958984
# reward is 7.00, reward sum is 98.85, time is 27.0, close is 29.82
#
# 56/100000
# action_prob: [0.31669778 0.47055945 0.21274275], action is hold
# action_loss: -41.90980911254883, Q_loss : -2.419099807739258
# reward is -1.00, reward sum is 97.85, time is 28.0, close is 29.81
#
# 57/100000
# action_prob: [0.3142706  0.4729684  0.21276107], action is buy
# action_loss: -42.31021499633789, Q_loss : -1.4230995178222656
# reward is -6.00, reward sum is 91.85, time is 29.0, close is 29.75
#
# 58/100000
# action_prob: [0.31184554 0.4753554  0.21279906], action is buy
# action_loss: -42.71044921875, Q_loss : 28.57289695739746
# reward is 7.00, reward sum is 98.85, time is 30.0, close is 29.82
#
# 59/100000
# action_prob: [0.30942622 0.4777189  0.21285489], action is sell
# action_loss: -43.11050033569336, Q_loss : 15.568899154663086
# reward is -5.00, reward sum is 93.85, time is 31.0, close is 29.77
#
# 60/100000
# action_prob: [0.30701604 0.4800571  0.21292686], action is hold
# action_loss: -43.51039123535156, Q_loss : -49.01710510253906
# reward is 11.00, reward sum is 104.85, time is 32.0, close is 29.88
#
# 61/100000
# action_prob: [0.3046183  0.48236844 0.21301323], action is buy
# action_loss: -43.910118103027344, Q_loss : -11.43910026550293
# reward is 7.00, reward sum is 111.85, time is 33.0, close is 29.95
#
# 62/100000
# action_prob: [0.30223647 0.48465118 0.21311244], action is sell
# action_loss: -44.30967330932617, Q_loss : 25.556903839111328
# reward is -2.00, reward sum is 109.85, time is 34.0, close is 29.93
#
# 63/100000
# action_prob: [0.2998737  0.4869035  0.21322277], action is sell
# action_loss: -44.709075927734375, Q_loss : -29.44708824157715
# reward is 12.00, reward sum is 121.85, time is 35.0, close is 30.05
#
# 64/100000
# action_prob: [0.29753333 0.4891239  0.21334277], action is sell
# action_loss: -45.10830307006836, Q_loss : 19.384916305541992
# reward is -6.00, reward sum is 115.85, time is 36.0, close is 29.99
#
# 65/100000
# action_prob: [0.29521835 0.49131075 0.21347092], action is buy
# action_loss: -45.507389068603516, Q_loss : 46.97932434082031
# reward is -9.00, reward sum is 106.85, time is 37.0, close is 29.9
#
# 66/100000
# action_prob: [0.2929317  0.4934625  0.21360584], action is sell
# action_loss: -45.90629577636719, Q_loss : 60.54093933105469
# reward is 6.00, reward sum is 112.85, time is 38.0, close is 29.96
#
# 67/100000
# action_prob: [0.29067618 0.4955777  0.21374618], action is sell
# action_loss: -46.30506134033203, Q_loss : 13.536949157714844
# reward is 3.00, reward sum is 115.85, time is 39.0, close is 29.99
#
# 68/100000
# action_prob: [0.2884544  0.49765494 0.21389066], action is sell
# action_loss: -46.70364761352539, Q_loss : 50.532962799072266
# reward is 6.00, reward sum is 121.85, time is 40.0, close is 30.05
#
# 69/100000
# action_prob: [0.28626883 0.49969298 0.21403815], action is hold
# action_loss: -47.102088928222656, Q_loss : -21.471023559570312
# reward is -11.00, reward sum is 110.85, time is 41.0, close is 29.94
#
# 70/100000
# action_prob: [0.28412175 0.50169075 0.2141875 ], action is sell
# action_loss: -47.50038146972656, Q_loss : -44.0570068359375
# reward is 1.00, reward sum is 111.85, time is 42.0, close is 29.95
#
# 71/100000
# action_prob: [0.2820152  0.5036471  0.21433772], action is hold
# action_loss: -47.89850616455078, Q_loss : -14.478982925415039
# reward is 5.00, reward sum is 116.85, time is 43.0, close is 30.0
#
# 72/100000
# action_prob: [0.27995098 0.5055612  0.21448782], action is hold
# action_loss: -48.29648971557617, Q_loss : 5.5170392990112305
# reward is 17.00, reward sum is 133.85, time is 44.0, close is 30.17
#
# 73/100000
# action_prob: [0.2779308  0.50743216 0.214637  ], action is buy
# action_loss: -48.69432067871094, Q_loss : 28.513057708740234
# reward is -15.00, reward sum is 118.85, time is 45.0, close is 30.02
#
# 74/100000
# action_prob: [0.27595603 0.5092595  0.21478444], action is buy
# action_loss: -49.09199523925781, Q_loss : 48.9434814453125
# reward is -10.00, reward sum is 108.85, time is 46.0, close is 29.92
#
# 75/100000
# action_prob: [0.27402788 0.51104265 0.21492948], action is sell
# action_loss: -49.48952102661133, Q_loss : 10.505102157592773
# reward is 4.00, reward sum is 112.85, time is 47.0, close is 29.96
#
# 76/100000
# action_prob: [0.27214736 0.5127812  0.21507142], action is sell
# action_loss: -49.886898040771484, Q_loss : 52.919132232666016
# reward is -10.00, reward sum is 102.85, time is 48.0, close is 29.86
#
# 77/100000
# action_prob: [0.27031514 0.514475   0.21520981], action is sell
# action_loss: -50.28413391113281, Q_loss : 32.915164947509766
# reward is -9.00, reward sum is 93.85, time is 0.0, close is 29.77
#
# 78/100000
# action_prob: [0.268532   0.51612395 0.21534409], action is sell
# action_loss: -50.68121337890625, Q_loss : 33.49317932128906
# reward is 12.40, reward sum is 106.26, time is 1.0, close is 29.9
#
# 79/100000
# action_prob: [0.26679817 0.5177279  0.21547394], action is sell
# action_loss: -51.078163146972656, Q_loss : -7.510786056518555
# reward is 0.00, reward sum is 106.26, time is 2.0, close is 29.8
#
# 80/100000
# action_prob: [0.26511386 0.5192872  0.21559894], action is hold
# action_loss: -51.474971771240234, Q_loss : -17.514753341674805
# reward is 0.00, reward sum is 106.26, time is 3.0, close is 29.58
#
# 81/100000
# action_prob: [0.26347914 0.520802   0.21571885], action is buy
# action_loss: -51.87163543701172, Q_loss : 58.48127746582031
# reward is -0.60, reward sum is 105.66, time is 4.0, close is 29.41
#
# 82/100000
# action_prob: [0.26189387 0.5222727  0.21583343], action is buy
# action_loss: -52.268150329589844, Q_loss : 41.477317810058594
# reward is 10.00, reward sum is 115.66, time is 5.0, close is 29.51
#
# 83/100000
# action_prob: [0.26035774 0.52369976 0.21594253], action is hold
# action_loss: -52.66454315185547, Q_loss : 42.473358154296875
# reward is -7.00, reward sum is 108.66, time is 6.0, close is 29.44
#
# 84/100000
# action_prob: [0.25887024 0.5250837  0.21604605], action is sell
# action_loss: -53.06079864501953, Q_loss : -5.112605094909668
# reward is 20.00, reward sum is 128.66, time is 7.0, close is 29.64
#
# 85/100000
# action_prob: [0.25743088 0.52642524 0.21614385], action is sell
# action_loss: -53.45692443847656, Q_loss : -46.66576385498047
# reward is 16.00, reward sum is 144.66, time is 8.0, close is 29.8
#
# 86/100000
# action_prob: [0.256039   0.527725   0.21623598], action is hold
# action_loss: -53.85292053222656, Q_loss : -73.53852844238281
# reward is 20.00, reward sum is 164.66, time is 9.0, close is 30.0
#
# 87/100000
# action_prob: [0.25469375 0.52898383 0.21632236], action is buy
# action_loss: -54.2487907409668, Q_loss : -28.124488830566406
# reward is 0.00, reward sum is 164.66, time is 10.0, close is 30.0
#
# 88/100000
# action_prob: [0.2533943  0.53020257 0.21640313], action is sell
# action_loss: -54.64453125, Q_loss : 47.857948303222656
# reward is -10.00, reward sum is 154.66, time is 11.0, close is 29.9
#
# 89/100000
# action_prob: [0.25213972 0.531382   0.21647824], action is buy
# action_loss: -55.0401611328125, Q_loss : 66.44960021972656
# reward is 10.00, reward sum is 164.66, time is 12.0, close is 30.0
#
# 90/100000
# action_prob: [0.25092894 0.53252316 0.2165479 ], action is sell
# action_loss: -55.4356689453125, Q_loss : 90.44564819335938
# reward is -6.00, reward sum is 158.66, time is 13.0, close is 29.94
#
# 91/100000
# action_prob: [0.2497609  0.533627   0.21661212], action is sell
# action_loss: -55.8310546875, Q_loss : 24.441688537597656
# reward is -2.00, reward sum is 156.66, time is 14.0, close is 29.92
#
# 92/100000
# action_prob: [0.24863449 0.53469443 0.21667105], action is sell
# action_loss: -56.22632598876953, Q_loss : -2.1442646980285645
# reward is -9.00, reward sum is 147.66, time is 15.0, close is 29.83
#
# 93/100000
# action_prob: [0.24754857 0.53572655 0.2167249 ], action is hold
# action_loss: -56.62149429321289, Q_loss : 39.43378448486328
# reward is -19.00, reward sum is 128.66, time is 16.0, close is 29.64
#
# 94/100000
# action_prob: [0.24650197 0.5367243  0.21677378], action is sell
# action_loss: -57.01654815673828, Q_loss : -94.57015991210938
# reward is 30.00, reward sum is 158.66, time is 17.0, close is 29.94
#
# 95/100000
# action_prob: [0.24549349 0.53768873 0.21681781], action is sell
# action_loss: -57.411495208740234, Q_loss : -54.57411193847656
# reward is -16.00, reward sum is 142.66, time is 18.0, close is 29.78
#
# 96/100000
# action_prob: [0.24452187 0.5386209  0.21685725], action is sell
# action_loss: -57.80633544921875, Q_loss : 0.8263387680053711
# reward is -9.00, reward sum is 133.66, time is 19.0, close is 29.69
#
# 97/100000
# action_prob: [0.24358597 0.5395218  0.21689226], action is buy
# action_loss: -58.201080322265625, Q_loss : 14.417991638183594
# reward is 11.00, reward sum is 144.66, time is 20.0, close is 29.8
#
# 98/100000
# action_prob: [0.24268456 0.54039246 0.216923  ], action is hold
# action_loss: -58.59571838378906, Q_loss : -19.585956573486328
# reward is 5.00, reward sum is 149.66, time is 21.0, close is 29.85
#
# 99/100000
# action_prob: [0.24181643 0.5412339  0.21694967], action is sell
# action_loss: -58.990257263183594, Q_loss : 108.41009521484375
# reward is 1.00, reward sum is 150.66, time is 22.0, close is 29.86
#
# 100/100000
# action_prob: [0.24098039 0.54204714 0.21697246], action is buy
# action_loss: -59.38471221923828, Q_loss : 9.406148910522461
# reward is 0.00, reward sum is 150.66, time is 23.0, close is 29.86
#
# 101/100000
# action_prob: [0.24017528 0.5428332  0.21699154], action is buy
# action_loss: -59.77907180786133, Q_loss : 44.80680465698242
# reward is -8.00, reward sum is 142.66, time is 24.0, close is 29.78
#
# 102/100000
# action_prob: [0.23939992 0.54359293 0.21700712], action is hold
# action_loss: -60.173343658447266, Q_loss : 61.39826965332031
# reward is 9.00, reward sum is 151.66, time is 25.0, close is 29.87
#
# 103/100000
# action_prob: [0.2386533  0.5443273  0.21701938], action is sell
# action_loss: -60.567527770996094, Q_loss : 18.798725128173828
# reward is -6.00, reward sum is 145.66, time is 26.0, close is 29.81
#
# 104/100000
# action_prob: [0.23793416 0.5450374  0.21702847], action is buy
# action_loss: -60.96162796020508, Q_loss : 37.390380859375
# reward is -13.00, reward sum is 132.66, time is 27.0, close is 29.68
#
# 105/100000
# action_prob: [0.23724149 0.5457239  0.2170346 ], action is hold
# action_loss: -61.35563278198242, Q_loss : -16.208955764770508
# reward is 12.00, reward sum is 144.66, time is 28.0, close is 29.8
#
# 106/100000
# action_prob: [0.23657428 0.5463878  0.2170379 ], action is buy
# action_loss: -61.749576568603516, Q_loss : 24.382509231567383
# reward is 20.00, reward sum is 164.66, time is 29.0, close is 30.0
#
# 107/100000
# action_prob: [0.23593146 0.5470299  0.21703859], action is hold
# action_loss: -62.14342498779297, Q_loss : 65.37857055664062
# reward is -4.00, reward sum is 160.66, time is 30.0, close is 29.96
#
# 108/100000
# action_prob: [0.23531209 0.54765105 0.2170368 ], action is sell
# action_loss: -62.53721237182617, Q_loss : 35.77922821044922
# reward is 4.00, reward sum is 164.66, time is 31.0, close is 30.0
#
# 109/100000
# action_prob: [0.23471521 0.54825217 0.21703269], action is sell
# action_loss: -62.93091583251953, Q_loss : -12.629310607910156
# reward is 20.00, reward sum is 184.66, time is 32.0, close is 30.2
#
# 110/100000
# action_prob: [0.23413984 0.5488338  0.21702635], action is buy
# action_loss: -63.32454299926758, Q_loss : -15.633240699768066
# reward is -13.00, reward sum is 171.66, time is 33.0, close is 30.07
#
# 111/100000
# action_prob: [0.23358521 0.5493968  0.21701804], action is hold
# action_loss: -63.718109130859375, Q_loss : 52.362831115722656
# reward is -7.00, reward sum is 164.66, time is 34.0, close is 30.0
#
# 112/100000
# action_prob: [0.23305038 0.54994184 0.21700776], action is sell
# action_loss: -64.11161041259766, Q_loss : -54.20671463012695
# reward is 0.00, reward sum is 164.66, time is 35.0, close is 30.0
#
# 113/100000
# action_prob: [0.23253451 0.5504697  0.21699573], action is hold
# action_loss: -64.50503540039062, Q_loss : 18.35495376586914
# reward is -10.00, reward sum is 154.66, time is 36.0, close is 29.9
#
# 114/100000
# action_prob: [0.2320369  0.55098104 0.21698207], action is sell
# action_loss: -64.89839935302734, Q_loss : -24.64899253845215
# reward is 5.00, reward sum is 159.66, time is 37.0, close is 29.95
#
# 115/100000
# action_prob: [0.23155674 0.5514764  0.21696687], action is buy
# action_loss: -65.29169464111328, Q_loss : 15.751686096191406
# reward is 0.00, reward sum is 159.66, time is 38.0, close is 29.95
#
# 116/100000
# action_prob: [0.23109329 0.55195653 0.21695025], action is hold
# action_loss: -65.6849365234375, Q_loss : 4.343148231506348
# reward is -11.00, reward sum is 148.66, time is 39.0, close is 29.84
#
# 117/100000
# action_prob: [0.23064584 0.55242187 0.2169323 ], action is sell
# action_loss: -66.07810974121094, Q_loss : 40.33921813964844
# reward is 4.00, reward sum is 152.66, time is 40.0, close is 29.88
#
# 118/100000
# action_prob: [0.23021378 0.5528731  0.21691315], action is sell
# action_loss: -66.47122955322266, Q_loss : 66.33528900146484
# reward is 4.00, reward sum is 156.66, time is 41.0, close is 29.92
#
# 119/100000
# action_prob: [0.22979642 0.55331075 0.21689287], action is buy
# action_loss: -66.86428833007812, Q_loss : 7.33135986328125
# reward is 3.00, reward sum is 159.66, time is 42.0, close is 29.95
#
# 120/100000
# action_prob: [0.22939315 0.5537353  0.21687156], action is sell
# action_loss: -67.2573013305664, Q_loss : 11.327430725097656
# reward is 0.00, reward sum is 159.66, time is 43.0, close is 29.95
#
# 121/100000
# action_prob: [0.2290034  0.5541473  0.21684931], action is sell
# action_loss: -67.65025329589844, Q_loss : 3.323500633239746
# reward is -9.00, reward sum is 150.66, time is 44.0, close is 29.86
#
# 122/100000
# action_prob: [0.22862661 0.5545472  0.2168262 ], action is sell
# action_loss: -68.04315948486328, Q_loss : 17.31957244873047
# reward is -9.00, reward sum is 141.66, time is 45.0, close is 29.77
#
# 123/100000
# action_prob: [0.22826222 0.55493546 0.21680228], action is buy
# action_loss: -68.4360122680664, Q_loss : 17.720239639282227
# reward is 8.00, reward sum is 149.66, time is 46.0, close is 29.85
#
# 124/100000
# action_prob: [0.22790974 0.5553126  0.21677767], action is sell
# action_loss: -68.82881164550781, Q_loss : -60.68828582763672
# reward is 12.00, reward sum is 161.66, time is 47.0, close is 29.97
#
# 125/100000
# action_prob: [0.22756869 0.5556789  0.21675241], action is sell
# action_loss: -69.22156524658203, Q_loss : 33.30778503417969
# reward is -10.00, reward sum is 151.66, time is 48.0, close is 29.87
#
# 126/100000
# action_prob: [0.2272386  0.55603486 0.21672653], action is sell
# action_loss: -69.61426544189453, Q_loss : 10.303855895996094
# reward is -107.00, reward sum is 44.66, time is 0.0, close is 28.8
#
# 127/100000
# action_prob: [0.22691897 0.55638087 0.21670015], action is sell
# action_loss: -70.00692749023438, Q_loss : -49.7000732421875
# reward is -0.59, reward sum is 44.07, time is 1.0, close is 28.8
#
# 128/100000
# action_prob: [0.22660945 0.5567173  0.2166733 ], action is sell
# action_loss: -70.3995361328125, Q_loss : 34.29600524902344
# reward is 0.00, reward sum is 44.07, time is 2.0, close is 28.71
#
# 129/100000
# action_prob: [0.22630957 0.5570444  0.216646  ], action is hold
# action_loss: -70.79210662841797, Q_loss : -26.707923889160156
# reward is 0.00, reward sum is 44.07, time is 3.0, close is 28.83
#
# 130/100000
# action_prob: [0.226019   0.5573627  0.21661833], action is sell
# action_loss: -71.18463134765625, Q_loss : -7.307242393493652
# reward is 0.00, reward sum is 44.07, time is 4.0, close is 28.96
#
# 131/100000
# action_prob: [0.22573732 0.5576723  0.21659033], action is sell
# action_loss: -71.57711791992188, Q_loss : 20.702228546142578
# reward is 0.00, reward sum is 44.07, time is 5.0, close is 28.99
#
# 132/100000
# action_prob: [0.22546421 0.55797374 0.21656206], action is sell
# action_loss: -71.96955871582031, Q_loss : -57.71969985961914
# reward is 0.00, reward sum is 44.07, time is 6.0, close is 29.0
#
# 133/100000
# action_prob: [0.22519927 0.55826724 0.21653353], action is buy
# action_loss: -72.36196899414062, Q_loss : 14.27638053894043
# reward is -0.58, reward sum is 43.49, time is 7.0, close is 29.0
#
# 134/100000
# action_prob: [0.22494228 0.5585529  0.2165048 ], action is sell
# action_loss: -72.75433349609375, Q_loss : -17.727540969848633
# reward is -9.00, reward sum is 34.49, time is 8.0, close is 28.91
#
# 135/100000
# action_prob: [0.22469285 0.5588313  0.21647589], action is sell
# action_loss: -73.14665222167969, Q_loss : 60.268531799316406
# reward is -4.00, reward sum is 30.49, time is 9.0, close is 28.87
#
# 136/100000
# action_prob: [0.22445074 0.5591025  0.21644683], action is sell
# action_loss: -73.53894805908203, Q_loss : -34.735389709472656
# reward is -1.00, reward sum is 29.49, time is 10.0, close is 28.86
#
# 137/100000
# action_prob: [0.22421561 0.5593667  0.21641764], action is sell
# action_loss: -73.93119049072266, Q_loss : 49.67869186401367
# reward is -5.00, reward sum is 24.49, time is 11.0, close is 28.81
#
# 138/100000
# action_prob: [0.22398724 0.5596244  0.21638837], action is sell
# action_loss: -74.32342529296875, Q_loss : -28.325233459472656
# reward is 8.00, reward sum is 32.49, time is 12.0, close is 28.89
#
# 139/100000
# action_prob: [0.22376536 0.55987555 0.21635905], action is buy
# action_loss: -74.71560668945312, Q_loss : -28.747156143188477
# reward is -8.00, reward sum is 24.49, time is 13.0, close is 28.81
#
# 140/100000
# action_prob: [0.22354972 0.5601205  0.21632972], action is hold
# action_loss: -75.1077651977539, Q_loss : 15.248924255371094
# reward is -4.00, reward sum is 20.49, time is 14.0, close is 28.77
#
# 141/100000
# action_prob: [0.22334011 0.56035954 0.21630035], action is hold
# action_loss: -75.49987030029297, Q_loss : -0.3370027542114258
# reward is 0.00, reward sum is 20.49, time is 15.0, close is 28.77
#
# 142/100000
# action_prob: [0.22313628 0.5605927  0.21627098], action is sell
# action_loss: -75.89196014404297, Q_loss : 78.2410888671875
# reward is 7.00, reward sum is 27.49, time is 16.0, close is 28.84
#
# 143/100000
# action_prob: [0.22293803 0.56082034 0.21624166], action is hold
# action_loss: -76.28401947021484, Q_loss : 24.237157821655273
# reward is 4.00, reward sum is 31.49, time is 17.0, close is 28.88
#
# 144/100000
# action_prob: [0.22274517 0.56104255 0.21621235], action is buy
# action_loss: -76.67603302001953, Q_loss : 32.23324203491211
# reward is 12.00, reward sum is 43.49, time is 18.0, close is 29.0
#
# 145/100000
# action_prob: [0.22255746 0.56125945 0.21618311], action is sell
# action_loss: -77.06803131103516, Q_loss : -47.3466796875
# reward is -15.00, reward sum is 28.49, time is 19.0, close is 28.85
#
# 146/100000
# action_prob: [0.22237477 0.5614713  0.21615395], action is hold
# action_loss: -77.45999145507812, Q_loss : 7.225406169891357
# reward is 1.00, reward sum is 29.49, time is 20.0, close is 28.86
#
# 147/100000
# action_prob: [0.22219686 0.56167823 0.21612486], action is sell
# action_loss: -77.85193634033203, Q_loss : 58.22147750854492
# reward is -11.00, reward sum is 18.49, time is 21.0, close is 28.75
#
# 148/100000
# action_prob: [0.22202362 0.56188047 0.21609591], action is hold
# action_loss: -78.24383544921875, Q_loss : -9.782434463500977
# reward is -6.00, reward sum is 12.49, time is 22.0, close is 28.69
#
# 149/100000
# action_prob: [0.22185485 0.5620781  0.21606703], action is sell
# action_loss: -78.63571166992188, Q_loss : 12.213638305664062
# reward is -13.00, reward sum is -0.51, time is 23.0, close is 28.56
#
# 150/100000
# action_prob: [0.22169042 0.5622713  0.2160383 ], action is hold
# action_loss: -79.0275650024414, Q_loss : 42.2097282409668
# reward is 8.00, reward sum is 7.49, time is 24.0, close is 28.64
#
# 151/100000
# action_prob: [0.22153015 0.5624601  0.21600972], action is sell
# action_loss: -79.41939544677734, Q_loss : 46.014610290527344
# reward is -21.00, reward sum is -13.51, time is 25.0, close is 28.43
#
# 152/100000
# action_prob: [0.22137393 0.56264484 0.21598123], action is buy
# action_loss: -79.81120300292969, Q_loss : 18.201889038085938
# reward is 2.00, reward sum is -11.51, time is 26.0, close is 28.45
#
# 153/100000
# action_prob: [0.22122158 0.56282544 0.21595293], action is sell
# action_loss: -80.20297241210938, Q_loss : 5.632368087768555
# reward is -7.00, reward sum is -18.51, time is 27.0, close is 28.38
#
# 154/100000
# action_prob: [0.22107303 0.56300217 0.2159248 ], action is buy
# action_loss: -80.59471130371094, Q_loss : 57.194053649902344
# reward is 2.00, reward sum is -16.51, time is 28.0, close is 28.4
#
# 155/100000
# action_prob: [0.2209281  0.5631751  0.21589682], action is sell
# action_loss: -80.98644256591797, Q_loss : -1.8098602294921875
# reward is -10.00, reward sum is -26.51, time is 29.0, close is 28.3
#
# 156/100000
# action_prob: [0.2207867  0.5633443  0.21586901], action is sell
# action_loss: -81.37813568115234, Q_loss : 27.18621826171875
# reward is -5.00, reward sum is -31.51, time is 30.0, close is 28.25
#
# 157/100000
# action_prob: [0.2206487  0.5635099  0.21584135], action is sell
# action_loss: -81.76982116699219, Q_loss : -41.81769943237305
# reward is -4.00, reward sum is -35.51, time is 31.0, close is 28.21
#
# 158/100000
# action_prob: [0.22051401 0.56367207 0.21581392], action is sell
# action_loss: -82.16148376464844, Q_loss : 70.17839050292969
# reward is 9.00, reward sum is -26.51, time is 32.0, close is 28.3
#
# 159/100000
# action_prob: [0.2203825  0.56383085 0.21578665], action is buy
# action_loss: -82.5531005859375, Q_loss : 20.00086784362793
# reward is 4.00, reward sum is -22.51, time is 33.0, close is 28.34
#
# 160/100000
# action_prob: [0.22025406 0.56398636 0.21575958], action is sell
# action_loss: -82.9447250366211, Q_loss : -44.82944869995117
# reward is -9.00, reward sum is -31.51, time is 34.0, close is 28.25
#
# 161/100000
# action_prob: [0.22012861 0.5641387  0.21573271], action is sell
# action_loss: -83.3363037109375, Q_loss : -3.8333587646484375
# reward is -9.00, reward sum is -40.51, time is 35.0, close is 28.16
#
# 162/100000
# action_prob: [0.22000606 0.5642879  0.21570602], action is buy
# action_loss: -83.72789001464844, Q_loss : 22.162715911865234
# reward is 4.00, reward sum is -36.51, time is 36.0, close is 28.2
#
# 163/100000
# action_prob: [0.21988632 0.5644341  0.21567954], action is sell
# action_loss: -84.11942291259766, Q_loss : -41.8411979675293
# reward is -13.00, reward sum is -49.51, time is 37.0, close is 28.07
#
# 164/100000
# action_prob: [0.2197693  0.5645774  0.21565326], action is sell
# action_loss: -84.51095581054688, Q_loss : -54.84510803222656
# reward is 12.00, reward sum is -37.51, time is 38.0, close is 28.19
#
# 165/100000
# action_prob: [0.2196549  0.56471795 0.2156272 ], action is buy
# action_loss: -84.90245819091797, Q_loss : 7.150972366333008
# reward is 9.00, reward sum is -28.51, time is 39.0, close is 28.28
#
# 166/100000
# action_prob: [0.21954305 0.56485564 0.21560133], action is sell
# action_loss: -85.29395294189453, Q_loss : -5.852936744689941
# reward is 0.00, reward sum is -28.51, time is 40.0, close is 28.28
#
# 167/100000
# action_prob: [0.21943368 0.56499064 0.21557567], action is hold
# action_loss: -85.68543243408203, Q_loss : 45.14314270019531
# reward is 2.00, reward sum is -26.51, time is 41.0, close is 28.3
#
# 168/100000
# action_prob: [0.2193267  0.5651231  0.21555023], action is sell
# action_loss: -86.07687377929688, Q_loss : 12.139232635498047
# reward is -7.00, reward sum is -33.51, time is 42.0, close is 28.23
#
# 169/100000
# action_prob: [0.2192221  0.56525296 0.21552502], action is buy
# action_loss: -86.46830749511719, Q_loss : 4.539913177490234
# reward is -15.00, reward sum is -48.51, time is 43.0, close is 28.08
#
# 170/100000
# action_prob: [0.21911971 0.56538033 0.2155    ], action is sell
# action_loss: -86.85971069335938, Q_loss : -0.8685989379882812
# reward is 16.00, reward sum is -32.51, time is 44.0, close is 28.24
#
# 171/100000
# action_prob: [0.21901953 0.56550527 0.21547516], action is sell
# action_loss: -87.25111389160156, Q_loss : 35.12749481201172
# reward is 16.00, reward sum is -16.51, time is 45.0, close is 28.4
#
# 172/100000
# action_prob: [0.2189215  0.565628   0.21545058], action is sell
# action_loss: -87.64248657226562, Q_loss : -89.87643432617188
# reward is -19.00, reward sum is -35.51, time is 46.0, close is 28.21
#
# 173/100000
# action_prob: [0.2188255  0.56574833 0.21542618], action is buy
# action_loss: -88.03385925292969, Q_loss : -12.88033676147461
# reward is -12.00, reward sum is -47.51, time is 47.0, close is 28.09
#
# 174/100000
# action_prob: [0.21873154 0.5658665  0.215402  ], action is buy
# action_loss: -88.42520141601562, Q_loss : 32.115753173828125
# reward is 25.00, reward sum is -22.51, time is 48.0, close is 28.34
#
# 175/100000
# action_prob: [0.21863951 0.56598246 0.21537806], action is sell
# action_loss: -88.8165283203125, Q_loss : -2.8881664276123047
# reward is -9.00, reward sum is -31.51, time is 0.0, close is 28.25
#
# 176/100000
# action_prob: [0.2185494  0.56609637 0.21535432], action is sell
# action_loss: -89.20783996582031, Q_loss : 3.960322380065918
# reward is 36.42, reward sum is 4.91, time is 1.0, close is 28.62
#
# 177/100000
# action_prob: [0.21846113 0.5662081  0.2153308 ], action is buy
# action_loss: -89.59915161132812, Q_loss : 30.1040096282959
# reward is -0.57, reward sum is 4.35, time is 2.0, close is 28.68
#
# 178/100000
# action_prob: [0.21837464 0.56631786 0.21530746], action is sell
# action_loss: -89.99042510986328, Q_loss : 17.100093841552734
# reward is -7.00, reward sum is -2.65, time is 3.0, close is 28.61
#
# 179/100000
# action_prob: [0.2182899  0.56642574 0.21528432], action is sell
# action_loss: -90.38168334960938, Q_loss : -48.90381622314453
# reward is 14.00, reward sum is 11.35, time is 4.0, close is 28.75
#
# 180/100000
# action_prob: [0.21820688 0.56653166 0.21526144], action is sell
# action_loss: -90.77293395996094, Q_loss : -24.907733917236328
# reward is 14.00, reward sum is 25.35, time is 5.0, close is 28.89
#
# 181/100000
# action_prob: [0.2181255  0.5666358  0.21523872], action is sell
# action_loss: -91.16416931152344, Q_loss : 43.08836364746094
# reward is 16.00, reward sum is 41.35, time is 6.0, close is 29.05
#
# 182/100000
# action_prob: [0.21804573 0.566738   0.21521623], action is sell
# action_loss: -91.55538940429688, Q_loss : 1.0844440460205078
# reward is -5.00, reward sum is 36.35, time is 7.0, close is 29.0
#
# 183/100000
# action_prob: [0.21796751 0.5668385  0.21519396], action is sell
# action_loss: -91.94659423828125, Q_loss : 41.50053405761719
# reward is 0.00, reward sum is 36.35, time is 8.0, close is 29.0
#
# 184/100000
# action_prob: [0.21789081 0.56693727 0.21517187], action is hold
# action_loss: -92.3377914428711, Q_loss : -64.4883804321289
# reward is 11.00, reward sum is 47.35, time is 9.0, close is 29.11
#
# 185/100000
# action_prob: [0.21781562 0.56703436 0.21515003], action is hold
# action_loss: -92.72896575927734, Q_loss : 35.072715759277344
# reward is -11.00, reward sum is 36.35, time is 10.0, close is 29.0
#
# 186/100000
# action_prob: [0.21774186 0.5671298  0.21512835], action is sell
# action_loss: -93.12013244628906, Q_loss : 26.47319984436035
# reward is 0.00, reward sum is 36.35, time is 11.0, close is 29.0
#
# 187/100000
# action_prob: [0.2176695  0.56722367 0.2151069 ], action is sell
# action_loss: -93.51128387451172, Q_loss : -8.500717163085938
# reward is 2.00, reward sum is 38.35, time is 12.0, close is 29.02
#
# 188/100000
# action_prob: [0.2175985  0.5673159  0.21508561], action is hold
# action_loss: -93.90242767333984, Q_loss : -41.93902587890625
# reward is -17.00, reward sum is 21.35, time is 13.0, close is 28.85
#
# 189/100000
# action_prob: [0.21752883 0.56740665 0.21506456], action is sell
# action_loss: -94.29354858398438, Q_loss : -17.942935943603516
# reward is 6.00, reward sum is 27.35, time is 14.0, close is 28.91
#
# 190/100000
# action_prob: [0.21746045 0.5674959  0.21504366], action is hold
# action_loss: -94.68466186523438, Q_loss : 28.270353317260742
# reward is 0.00, reward sum is 27.35, time is 15.0, close is 28.91
#
# 191/100000
# action_prob: [0.21739335 0.5675836  0.215023  ], action is buy
# action_loss: -95.07575988769531, Q_loss : 35.90764236450195
# reward is 1.00, reward sum is 28.35, time is 16.0, close is 28.92
#
# 192/100000
# action_prob: [0.21732749 0.5676699  0.21500252], action is hold
# action_loss: -95.46685028076172, Q_loss : 6.0453338623046875
# reward is -11.00, reward sum is 17.35, time is 17.0, close is 28.81
#
# 193/100000
# action_prob: [0.21726285 0.56775486 0.21498223], action is buy
# action_loss: -95.85792541503906, Q_loss : -4.958576202392578
# reward is -21.00, reward sum is -3.65, time is 18.0, close is 28.6
#
# 194/100000
# action_prob: [0.2171994  0.5678385  0.21496214], action is sell
# action_loss: -96.24897766113281, Q_loss : 51.037513732910156
# reward is -7.00, reward sum is -10.65, time is 19.0, close is 28.53
#
# 195/100000
# action_prob: [0.2171371  0.5679207  0.21494223], action is sell
# action_loss: -96.64002990722656, Q_loss : -56.96639633178711
# reward is 2.00, reward sum is -8.65, time is 20.0, close is 28.55
#
# 196/100000
# action_prob: [0.2170759 0.5680016 0.2149225], action is sell
# action_loss: -97.03108215332031, Q_loss : 4.029693603515625
# reward is -20.00, reward sum is -28.65, time is 21.0, close is 28.35
#
# 197/100000
# action_prob: [0.21701579 0.56808126 0.21490295], action is sell
# action_loss: -97.42211151123047, Q_loss : -70.97421264648438
# reward is 7.00, reward sum is -21.65, time is 22.0, close is 28.42
#
# 198/100000
# action_prob: [0.21695673 0.56815964 0.21488361], action is hold
# action_loss: -97.81312561035156, Q_loss : 83.89067077636719
# reward is -1.00, reward sum is -22.65, time is 23.0, close is 28.41
#
# 199/100000
# action_prob: [0.21689874 0.5682369  0.21486443], action is sell
# action_loss: -98.20413208007812, Q_loss : 5.017963409423828
# reward is -1.00, reward sum is -23.65, time is 24.0, close is 28.4
#
# 200/100000
# action_prob: [0.21684176 0.5683128  0.21484545], action is hold
# action_loss: -98.59513854980469, Q_loss : -99.98594665527344
# reward is 13.00, reward sum is -10.65, time is 25.0, close is 28.53
#
# 201/100000
# action_prob: [0.21678577 0.56838757 0.21482663], action is sell
# action_loss: -98.98612213134766, Q_loss : -46.9898567199707
# reward is -2.00, reward sum is -12.65, time is 26.0, close is 28.51
#
# 202/100000
# action_prob: [0.21673076 0.5684613  0.21480799], action is sell
# action_loss: -99.37709045410156, Q_loss : -49.99376678466797
# reward is -6.00, reward sum is -18.65, time is 27.0, close is 28.45
#
# 203/100000
# action_prob: [0.21667668 0.5685338  0.21478951], action is hold
# action_loss: -99.76806640625, Q_loss : 4.002323150634766
# reward is 16.00, reward sum is -2.65, time is 28.0, close is 28.61
#
# 204/100000
# action_prob: [0.21662351 0.5686052  0.21477123], action is buy
# action_loss: -100.15901184082031, Q_loss : -16.59318733215332
# reward is -11.00, reward sum is -13.65, time is 29.0, close is 28.5
#
# 205/100000
# action_prob: [0.21657127 0.5686755  0.21475314], action is sell
# action_loss: -100.54997253417969, Q_loss : 19.994503021240234
# reward is 2.00, reward sum is -11.65, time is 30.0, close is 28.52
#
# 206/100000
# action_prob: [0.2165199  0.5687449  0.21473518], action is sell
# action_loss: -100.9408950805664, Q_loss : -41.00940704345703
# reward is 3.00, reward sum is -8.65, time is 31.0, close is 28.55
#
# 207/100000
# action_prob: [0.21646942 0.5688132  0.21471742], action is buy
# action_loss: -101.33181762695312, Q_loss : -33.59531784057617
# reward is 14.00, reward sum is 5.35, time is 32.0, close is 28.69
#
# 208/100000
# action_prob: [0.21641977 0.5688805  0.2146998 ], action is sell
# action_loss: -101.72274780273438, Q_loss : 67.98277282714844
# reward is -9.00, reward sum is -3.65, time is 33.0, close is 28.6
#
# 209/100000
# action_prob: [0.21637093 0.5689467  0.21468236], action is buy
# action_loss: -102.1136474609375, Q_loss : 4.9788665771484375
# reward is -2.00, reward sum is -5.65, time is 34.0, close is 28.58
#
# 210/100000
# action_prob: [0.21632288 0.56901205 0.21466507], action is buy
# action_loss: -102.5045394897461, Q_loss : 8.974952697753906
# reward is -3.00, reward sum is -8.65, time is 35.0, close is 28.55
#
# 211/100000
# action_prob: [0.21627565 0.56907636 0.21464793], action is sell
# action_loss: -102.89542388916016, Q_loss : -28.169958114624023
# reward is -1.00, reward sum is -9.65, time is 36.0, close is 28.54
#
# 212/100000
# action_prob: [0.21622919 0.56913984 0.214631  ], action is sell
# action_loss: -103.28631591796875, Q_loss : -15.032859802246094
# reward is 24.00, reward sum is 14.35, time is 37.0, close is 28.78
#
# 213/100000
# action_prob: [0.21618344 0.56920236 0.21461418], action is hold
# action_loss: -103.67718505859375, Q_loss : -9.036767959594727
# reward is 0.00, reward sum is 14.35, time is 38.0, close is 28.78
#
# 214/100000
# action_prob: [0.2161385  0.569264   0.21459754], action is sell
# action_loss: -104.06805419921875, Q_loss : -11.04068374633789
# reward is -7.00, reward sum is 7.35, time is 39.0, close is 28.71
#
# 215/100000
# action_prob: [0.21609421 0.56932473 0.21458103], action is hold
# action_loss: -104.4588851928711, Q_loss : 21.389812469482422
# reward is 3.00, reward sum is 10.35, time is 40.0, close is 28.74
#
# 216/100000
# action_prob: [0.21605068 0.56938463 0.21456471], action is sell
# action_loss: -104.84974670410156, Q_loss : 20.951499938964844
# reward is 2.00, reward sum is 12.35, time is 41.0, close is 28.76
#
# 217/100000
# action_prob: [0.21600778 0.5694437  0.21454853], action is buy
# action_loss: -105.24058532714844, Q_loss : 5.351993560791016
# reward is -1.00, reward sum is 11.35, time is 42.0, close is 28.75
#
# 218/100000
# action_prob: [0.21596561 0.5695019  0.21453246], action is sell
# action_loss: -105.63140106201172, Q_loss : -51.638309478759766
# reward is 3.00, reward sum is 14.35, time is 43.0, close is 28.78
#
# 219/100000
# action_prob: [0.21592408 0.56955934 0.2145166 ], action is sell
# action_loss: -106.02222442626953, Q_loss : -24.62582015991211
# reward is -18.00, reward sum is -3.65, time is 44.0, close is 28.6
#
# 220/100000
# action_prob: [0.21588318 0.56961596 0.21450086], action is hold
# action_loss: -106.41304016113281, Q_loss : -17.064128875732422
# reward is -11.00, reward sum is -14.65, time is 45.0, close is 28.49
#
# 221/100000
# action_prob: [0.21584293 0.5696718  0.21448524], action is buy
# action_loss: -106.80384826660156, Q_loss : -11.068038940429688
# reward is 5.00, reward sum is -9.65, time is 46.0, close is 28.54
#
# 222/100000
# action_prob: [0.21580331 0.56972694 0.21446982], action is sell
# action_loss: -107.19462585449219, Q_loss : -5.235949516296387
# reward is -4.00, reward sum is -13.65, time is 47.0, close is 28.5
#
# 223/100000
# action_prob: [0.2157643  0.56978124 0.21445449], action is sell
# action_loss: -107.58541870117188, Q_loss : 15.92414665222168
# reward is -9.00, reward sum is -22.65, time is 48.0, close is 28.41
#
# 224/100000
# action_prob: [0.21572585 0.5698349  0.21443932], action is buy
# action_loss: -107.9762191772461, Q_loss : 10.920242309570312
# reward is 0.00, reward sum is -22.65, time is 0.0, close is 28.41
#
# 225/100000
# action_prob: [0.21568803 0.5698877  0.21442428], action is hold
# action_loss: -108.36698913574219, Q_loss : -11.083669662475586
# reward is -16.00, reward sum is -38.65, time is 1.0, close is 28.25
#
# 226/100000
# action_prob: [0.21565075 0.5699399  0.21440937], action is sell
# action_loss: -108.75774383544922, Q_loss : 17.31682014465332
# reward is 13.43, reward sum is -25.22, time is 2.0, close is 28.39
#
# 227/100000
# action_prob: [0.21561404 0.56999135 0.2143946 ], action is sell
# action_loss: -109.14849090576172, Q_loss : -161.0914764404297
# reward is 0.00, reward sum is -25.22, time is 3.0, close is 28.35
#
# 228/100000
# action_prob: [0.21558034 0.5700372  0.21438242], action is sell
# action_loss: -109.53925323486328, Q_loss : 52.30921173095703
# reward is 0.00, reward sum is -25.22, time is 4.0, close is 28.32
#
# 229/100000
# action_prob: [0.21554226 0.57009226 0.2143655 ], action is sell
# action_loss: -109.93000030517578, Q_loss : 5.3350982666015625
# reward is 0.00, reward sum is -25.22, time is 5.0, close is 28.4
#
# 230/100000
# action_prob: [0.21550716 0.5701417  0.21435112], action is hold
# action_loss: -110.32072448730469, Q_loss : -38.10321044921875
# reward is 0.00, reward sum is -25.22, time is 6.0, close is 28.68
#
# 231/100000
# action_prob: [0.21547256 0.57019055 0.21433689], action is sell
# action_loss: -110.7114486694336, Q_loss : 32.89289093017578
# reward is 0.00, reward sum is -25.22, time is 7.0, close is 28.48
#
# 232/100000
# action_prob: [0.21543853 0.57023865 0.2143228 ], action is sell
# action_loss: -111.10218048095703, Q_loss : 4.88897705078125
# reward is 0.00, reward sum is -25.22, time is 8.0, close is 28.47
#
# 233/100000
# action_prob: [0.21540493 0.5702863  0.21430881], action is hold
# action_loss: -111.49291229248047, Q_loss : -30.690927505493164
# reward is 0.00, reward sum is -25.22, time is 9.0, close is 28.4
#
# 234/100000
# action_prob: [0.21537183 0.5703332  0.21429496], action is sell
# action_loss: -111.88359069824219, Q_loss : 7.3011627197265625
# reward is 0.00, reward sum is -25.22, time is 10.0, close is 28.45
#
# 235/100000
# action_prob: [0.21533923 0.57037956 0.21428122], action is sell
# action_loss: -112.27430725097656, Q_loss : -45.12274169921875
# reward is 0.00, reward sum is -25.22, time is 11.0, close is 28.35
#
# 236/100000
# action_prob: [0.21530707 0.5704253  0.2142676 ], action is sell
# action_loss: -112.6650161743164, Q_loss : -70.12664794921875
# reward is 0.00, reward sum is -25.22, time is 12.0, close is 28.41
#
# 237/100000
# action_prob: [0.21527538 0.57047045 0.21425413], action is hold
# action_loss: -113.05570983886719, Q_loss : -37.13055419921875
# reward is 0.00, reward sum is -25.22, time is 13.0, close is 28.35
#
# 238/100000
# action_prob: [0.21524416 0.57051504 0.21424076], action is hold
# action_loss: -113.44638061523438, Q_loss : 24.678333282470703
# reward is 0.00, reward sum is -25.22, time is 14.0, close is 28.2
#
# 239/100000
# action_prob: [0.21521336 0.57055914 0.21422748], action is hold
# action_loss: -113.83706665039062, Q_loss : -8.138374328613281
# reward is 0.00, reward sum is -25.22, time is 15.0, close is 28.15
#
# 240/100000
# action_prob: [0.21518299 0.5706026  0.21421435], action is sell
# action_loss: -114.22772216796875, Q_loss : 54.85633850097656
# reward is 0.00, reward sum is -25.22, time is 16.0, close is 27.91
#
# 241/100000
# action_prob: [0.21515307 0.57064563 0.21420138], action is buy
# action_loss: -114.61839294433594, Q_loss : -20.146183013916016
# reward is -0.57, reward sum is -25.79, time is 17.0, close is 27.91
#
# 242/100000
# action_prob: [0.21512355 0.570688   0.21418846], action is hold
# ...
#
# 7067/100000
# action_prob: [0.21194282 0.5761126  0.21194454], action is sell
# action_loss: -2776.994140625, Q_loss : -27.779773712158203
# reward is -9.96, reward sum is 2748.59, time is 32.0, close is 56.3789
#
# 7068/100000
# action_prob: [0.21194282 0.5761126  0.21194454], action is buy
# action_loss: -2777.38427734375, Q_loss : -20.823741912841797
# reward is -9.96, reward sum is 2738.63, time is 33.0, close is 56.2793
#
# 7069/100000
# action_prob: [0.21194282 0.5761126  0.21194454], action is sell
# action_loss: -2777.77392578125, Q_loss : 17.935630798339844
# reward is 24.90, reward sum is 2763.53, time is 34.0, close is 56.5283
#
# 7070/100000
# action_prob: [0.21194282 0.5761126  0.21194454], action is sell
# action_loss: -2778.164306640625, Q_loss : -11.921677589416504
# reward is 2.99, reward sum is 2766.52, time is 35.0, close is 56.5582
#
# 7071/100000
# action_prob: [0.21194282 0.5761126  0.21194454], action is sell
# action_loss: -2778.55419921875, Q_loss : -145.3256378173828
# reward is 31.88, reward sum is 2798.40, time is 36.0, close is 56.876999999999995
#
# 7072/100000
# action_prob: [0.2119428  0.5761126  0.21194454], action is hold
# action_loss: -2778.944091796875, Q_loss : 27.37662124633789
# reward is -12.95, reward sum is 2785.45, time is 37.0, close is 56.7475
#
# 7073/100000
# action_prob: [0.2119428  0.5761126  0.21194454], action is hold
# action_loss: -2779.33447265625, Q_loss : -21.823274612426758
# reward is 15.93, reward sum is 2801.38, time is 38.0, close is 56.9068
#
# 7074/100000
# action_prob: [0.21194282 0.5761127  0.21194454], action is sell
# action_loss: -2779.724365234375, Q_loss : -66.61724090576172
# reward is 56.78, reward sum is 2858.16, time is 39.0, close is 57.4746
#
# 7075/100000
# action_prob: [0.21194282 0.5761127  0.21194454], action is hold
# action_loss: -2780.1142578125, Q_loss : 14.305862426757812
# reward is 37.85, reward sum is 2896.01, time is 40.0, close is 57.8531
#
# 7076/100000
# action_prob: [0.21194282 0.5761127  0.21194454], action is sell
# action_loss: -2780.50439453125, Q_loss : -27.79486846923828
# reward is -2.99, reward sum is 2893.02, time is 41.0, close is 57.8232
#
# 7077/100000
# action_prob: [0.21194282 0.5761127  0.21194454], action is hold
# action_loss: -2780.89453125, Q_loss : -60.48786544799805
# reward is -24.90, reward sum is 2868.12, time is 42.0, close is 57.5742
#
# 7078/100000
# action_prob: [0.21194282 0.5761127  0.21194454], action is hold
# action_loss: -2781.284423828125, Q_loss : -43.752803802490234
# reward is 17.93, reward sum is 2886.05, time is 43.0, close is 57.7535
#
# 7079/100000
# action_prob: [0.21194282 0.5761127  0.21194454], action is sell
# action_loss: -2781.674560546875, Q_loss : -16.846769332885742
# reward is -24.90, reward sum is 2861.15, time is 44.0, close is 57.5045
#
# 7080/100000
# action_prob: [0.21194282 0.5761127  0.21194454], action is sell
# action_loss: -2782.064453125, Q_loss : -58.70073699951172
# reward is -60.76, reward sum is 2800.39, time is 45.0, close is 56.8969
#
# 7081/100000
# action_prob: [0.21194282 0.5761127  0.21194454], action is sell
# action_loss: -2782.454833984375, Q_loss : -46.377235412597656
# reward is -21.92, reward sum is 2778.47, time is 46.0, close is 56.6777
#
# 7082/100000
# action_prob: [0.21194282 0.5761127  0.21194452], action is sell
# action_loss: -2782.8447265625, Q_loss : 79.77163696289062
# reward is -3.98, reward sum is 2774.49, time is 47.0, close is 56.6379
#
# 7083/100000
# action_prob: [0.21194282 0.5761127  0.21194452], action is sell
# action_loss: -2783.23486328125, Q_loss : 23.967660903930664
# reward is -11.95, reward sum is 2762.54, time is 48.0, close is 56.5184
#
# 7084/100000
# action_prob: [0.21194282 0.5761127  0.21194452], action is buy
# action_loss: -2783.625, Q_loss : -45.441890716552734
# reward is 0.00, reward sum is 2762.54, time is 0.0, close is 56.5184
#
# 7085/100000
# action_prob: [0.21194282 0.5761127  0.21194452], action is hold
# action_loss: -2784.01416015625, Q_loss : 53.22998809814453
# reward is 0.00, reward sum is 2762.54, time is 1.0, close is 56.5184
#
# 7086/100000
# action_prob: [0.21194282 0.5761127  0.21194452], action is hold
# action_loss: -2784.40478515625, Q_loss : -12.903934478759766
# reward is 0.00, reward sum is 2762.54, time is 2.0, close is 56.5184
#
# 7087/100000
# action_prob: [0.21194282 0.5761127  0.21194452], action is buy
# action_loss: -2784.794677734375, Q_loss : -72.40098571777344
# reward is 0.00, reward sum is 2762.54, time is 3.0, close is 56.5184
#
# 7088/100000
# action_prob: [0.21194282 0.5761127  0.21194452], action is sell
# action_loss: -2785.1845703125, Q_loss : -26.0731201171875
# reward is -1.13, reward sum is 2761.41, time is 4.0, close is 56.5184
#
# 7089/100000
# action_prob: [0.21194282 0.5761127  0.2119445 ], action is sell
# action_loss: -2785.574951171875, Q_loss : -13.80583381652832
# reward is 0.00, reward sum is 2761.41, time is 5.0, close is 56.5184
#
# 7090/100000
# action_prob: [0.21194282 0.5761127  0.2119445 ], action is buy
# action_loss: -2785.96484375, Q_loss : -29.74817657470703
# reward is -1.13, reward sum is 2760.28, time is 6.0, close is 56.5184
#
# 7091/100000
# action_prob: [0.21194282 0.5761127  0.2119445 ], action is sell
# action_loss: -2786.35498046875, Q_loss : -53.6302490234375
# reward is 0.00, reward sum is 2760.28, time is 7.0, close is 56.5184
#
# 7092/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is buy
# action_loss: -2786.7451171875, Q_loss : 12.99256706237793
# reward is 0.00, reward sum is 2760.28, time is 8.0, close is 56.5184
#
# 7093/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is sell
# action_loss: -2787.134765625, Q_loss : -2.0313987731933594
# reward is 0.00, reward sum is 2760.28, time is 9.0, close is 56.5184
#
# 7094/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is sell
# action_loss: -2787.52490234375, Q_loss : -72.68536376953125
# reward is 0.00, reward sum is 2760.28, time is 10.0, close is 56.5184
#
# 7095/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is sell
# action_loss: -2787.9150390625, Q_loss : 9.900972366333008
# reward is 0.00, reward sum is 2760.28, time is 11.0, close is 56.5184
#
# 7096/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is hold
# action_loss: -2788.30517578125, Q_loss : -106.58299255371094
# reward is 0.00, reward sum is 2760.28, time is 12.0, close is 56.5184
#
# 7097/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is buy
# action_loss: -2788.6953125, Q_loss : -42.989356994628906
# reward is 0.00, reward sum is 2760.28, time is 13.0, close is 56.5184
#
# 7098/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is sell
# action_loss: -2789.0849609375, Q_loss : 9.949069023132324
# reward is 0.00, reward sum is 2760.28, time is 14.0, close is 56.5184
#
# 7099/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is hold
# action_loss: -2789.475341796875, Q_loss : -2.0045928955078125
# reward is 0.00, reward sum is 2760.28, time is 15.0, close is 56.5184
#
# 7100/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is sell
# action_loss: -2789.865478515625, Q_loss : -43.82855987548828
# reward is 0.00, reward sum is 2760.28, time is 16.0, close is 56.5184
#
# 7101/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is sell
# action_loss: -2790.255126953125, Q_loss : -69.74252319335938
# reward is 0.00, reward sum is 2760.28, time is 17.0, close is 56.5184
#
# 7102/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is hold
# action_loss: -2790.6455078125, Q_loss : 62.843505859375
# reward is 0.00, reward sum is 2760.28, time is 18.0, close is 56.5184
#
# 7103/100000
# action_prob: [0.21194279 0.5761127  0.2119445 ], action is sell
# action_loss: -2791.03515625, Q_loss : 5.9195404052734375
# reward is 0.00, reward sum is 2760.28, time is 19.0, close is 56.5184
#
# 7104/100000
# action_prob: [0.2119428  0.57611275 0.21194449], action is sell
# action_loss: -2791.42529296875, Q_loss : -134.51412963867188
# reward is 0.00, reward sum is 2760.28, time is 20.0, close is 56.5184
#
# 7105/100000
# action_prob: [0.2119428  0.57611275 0.21194449], action is sell
# action_loss: -2791.81591796875, Q_loss : 25.861907958984375
# reward is 0.00, reward sum is 2760.28, time is 21.0, close is 56.5184
#
# 7106/100000
# action_prob: [0.2119428  0.57611275 0.21194449], action is sell
# action_loss: -2792.20556640625, Q_loss : -28.782054901123047
# reward is 0.00, reward sum is 2760.28, time is 22.0, close is 56.5184
#
# 7107/100000
# action_prob: [0.21194279 0.57611275 0.21194449], action is sell
# action_loss: -2792.59521484375, Q_loss : -68.7960205078125
# reward is 0.00, reward sum is 2760.28, time is 23.0, close is 56.5184
#
# 7108/100000
# action_prob: [0.21194279 0.57611275 0.21194449], action is hold
# action_loss: -2792.985595703125, Q_loss : 9.850322723388672
# reward is 0.00, reward sum is 2760.28, time is 24.0, close is 56.5184
#
# 7109/100000
# action_prob: [0.21194279 0.57611275 0.21194449], action is buy
# action_loss: -2793.37548828125, Q_loss : -62.84365463256836
# reward is 0.00, reward sum is 2760.28, time is 25.0, close is 56.5184
#
# 7110/100000
# action_prob: [0.21194279 0.57611275 0.21194449], action is buy
# action_loss: -2793.765625, Q_loss : -37.86762237548828
# reward is 0.00, reward sum is 2760.28, time is 26.0, close is 56.5184
#
# 7111/100000
# action_prob: [0.21194279 0.57611275 0.21194448], action is hold
# action_loss: -2794.155517578125, Q_loss : -18.582435607910156
# reward is 0.00, reward sum is 2760.28, time is 27.0, close is 56.5184
#
# 7112/100000
# action_prob: [0.21194279 0.57611275 0.21194448], action is sell
# action_loss: -2794.545654296875, Q_loss : 22.814441680908203
# reward is 0.00, reward sum is 2760.28, time is 28.0, close is 56.5184
#
# 7113/100000
# action_prob: [0.21194279 0.57611275 0.21194448], action is hold
# action_loss: -2794.93603515625, Q_loss : -27.736125946044922
# reward is 0.00, reward sum is 2760.28, time is 29.0, close is 56.5184
#
# 7114/100000
# action_prob: [0.21194279 0.57611275 0.21194448], action is sell
# action_loss: -2795.325927734375, Q_loss : 15.926814079284668
# reward is 0.00, reward sum is 2760.28, time is 30.0, close is 56.5184
#
# 7115/100000
# action_prob: [0.21194279 0.57611275 0.21194448], action is sell
# action_loss: -2795.7158203125, Q_loss : -6.003084182739258
# reward is 0.00, reward sum is 2760.28, time is 31.0, close is 56.5184
#
# 7116/100000
# action_prob: [0.21194279 0.57611275 0.21194448], action is sell
# action_loss: -2796.10595703125, Q_loss : -60.831119537353516
# reward is 0.00, reward sum is 2760.28, time is 32.0, close is 56.5184
#
# 7117/100000
# action_prob: [0.21194279 0.57611275 0.21194448], action is sell
# action_loss: -2796.49560546875, Q_loss : -174.29327392578125
# reward is 0.00, reward sum is 2760.28, time is 33.0, close is 56.5184
#
# 7118/100000
# action_prob: [0.21194279 0.57611275 0.21194448], action is buy
# action_loss: -2796.885986328125, Q_loss : 22.373048782348633
# reward is 0.00, reward sum is 2760.28, time is 34.0, close is 56.5184
#
# 7119/100000
# action_prob: [0.21194279 0.57611275 0.21194446], action is sell
# action_loss: -2797.275634765625, Q_loss : -45.85271453857422
# reward is 0.00, reward sum is 2760.28, time is 35.0, close is 56.5184
#
# 7120/100000
# action_prob: [0.21194279 0.57611275 0.21194446], action is buy
# action_loss: -2797.665771484375, Q_loss : 8.883316040039062
# reward is 0.00, reward sum is 2760.28, time is 36.0, close is 56.5184
#
# 7121/100000
# action_prob: [0.21194279 0.57611275 0.21194446], action is sell
# action_loss: -2798.05615234375, Q_loss : -48.920650482177734
# reward is 0.00, reward sum is 2760.28, time is 37.0, close is 56.5184
#
# 7122/100000
# action_prob: [0.21194278 0.57611275 0.21194446], action is hold
# action_loss: -2798.446044921875, Q_loss : 46.82568359375
# reward is 0.00, reward sum is 2760.28, time is 38.0, close is 56.5184
#
# 7123/100000
# action_prob: [0.21194278 0.57611275 0.21194446], action is sell
# action_loss: -2798.8359375, Q_loss : 9.931718826293945
# reward is 0.00, reward sum is 2760.28, time is 39.0, close is 56.5184
#
# 7124/100000
# action_prob: [0.21194278 0.57611275 0.21194446], action is hold
# action_loss: -2799.22607421875, Q_loss : -10.15974235534668
# reward is 0.00, reward sum is 2760.28, time is 40.0, close is 56.5184
#
# 7125/100000
# action_prob: [0.21194278 0.57611275 0.21194446], action is sell
# action_loss: -2799.61572265625, Q_loss : -74.81621551513672
# reward is 0.00, reward sum is 2760.28, time is 41.0, close is 56.5184
#
# 7126/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is sell
# action_loss: -2800.006103515625, Q_loss : -30.333402633666992
# reward is 0.00, reward sum is 2760.28, time is 42.0, close is 56.5184
#
# 7127/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is hold
# action_loss: -2800.39599609375, Q_loss : 73.61615753173828
# reward is 0.00, reward sum is 2760.28, time is 43.0, close is 56.5184
#
# 7128/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is hold
# action_loss: -2800.7861328125, Q_loss : 9.922713279724121
# reward is 0.00, reward sum is 2760.28, time is 44.0, close is 56.5184
#
# 7129/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is sell
# action_loss: -2801.176513671875, Q_loss : -55.81177520751953
# reward is 0.00, reward sum is 2760.28, time is 45.0, close is 56.5184
#
# 7130/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is buy
# action_loss: -2801.566162109375, Q_loss : -26.015748977661133
# reward is 0.00, reward sum is 2760.28, time is 46.0, close is 56.5184
#
# 7131/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is sell
# action_loss: -2801.9560546875, Q_loss : -62.90940856933594
# reward is 0.00, reward sum is 2760.28, time is 47.0, close is 56.5184
#
# 7132/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is hold
# action_loss: -2802.346435546875, Q_loss : -102.76337432861328
# reward is 0.00, reward sum is 2760.28, time is 48.0, close is 56.5184
#
# 7133/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is hold
# action_loss: -2802.736328125, Q_loss : -66.95722961425781
# reward is -53.79, reward sum is 2706.49, time is 0.0, close is 55.9805
#
# 7134/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is hold
# action_loss: -2803.12646484375, Q_loss : 115.41869354248047
# reward is 7.97, reward sum is 2714.46, time is 1.0, close is 56.0602
#
# 7135/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is buy
# action_loss: -2803.51611328125, Q_loss : -139.59527587890625
# reward is -17.93, reward sum is 2696.53, time is 2.0, close is 55.8809
#
# 7136/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is sell
# action_loss: -2803.90625, Q_loss : -39.998939514160156
# reward is -31.02, reward sum is 2665.51, time is 3.0, close is 55.582
#
# 7137/100000
# action_prob: [0.21194279 0.5761128  0.21194446], action is sell
# action_loss: -2804.296630859375, Q_loss : -31.238422393798828
# reward is 0.00, reward sum is 2665.51, time is 4.0, close is 55.602
#
# 7138/100000
# action_prob: [0.21194278 0.5761128  0.21194446], action is sell
# action_loss: -2804.6865234375, Q_loss : -87.76687622070312
# reward is 0.00, reward sum is 2665.51, time is 5.0, close is 55.3828
#
# 7139/100000
# action_prob: [0.21194278 0.5761128  0.21194446], action is buy
# action_loss: -2805.076171875, Q_loss : -104.85083770751953
# reward is -1.12, reward sum is 2664.39, time is 6.0, close is 55.6816
#
# 7140/100000
# action_prob: [0.21194278 0.5761128  0.21194446], action is sell
# action_loss: -2805.466552734375, Q_loss : 37.7654914855957
# reward is 4.98, reward sum is 2669.37, time is 7.0, close is 55.7314
#
# 7141/100000
# action_prob: [0.21194278 0.5761128  0.21194442], action is buy
# action_loss: -2805.856689453125, Q_loss : -66.9084701538086
# reward is -14.94, reward sum is 2654.43, time is 8.0, close is 55.582
#
# 7142/100000
# action_prob: [0.21194278 0.5761128  0.21194442], action is buy
# action_loss: -2806.24658203125, Q_loss : -109.56306457519531
# reward is 18.93, reward sum is 2673.36, time is 9.0, close is 55.7713
#
# 7143/100000
# action_prob: [0.21194278 0.5761128  0.21194442], action is sell
# action_loss: -2806.63671875, Q_loss : -50.8064079284668
# reward is -7.97, reward sum is 2665.39, time is 10.0, close is 55.6916
#
# 7144/100000
# action_prob: [0.21194278 0.5761128  0.21194442], action is sell

# %%
agent._data_set._buffer
